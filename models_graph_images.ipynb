# %%
from IPython.display import Image

from simple_chatboot import graph

Image(graph.get_graph().draw_mermaid_png())

# %%
from IPython.display import Image

from complex_chatboot import graph

Image(graph.get_graph().draw_mermaid_png())

# %%
from IPython.display import Image

from notebook_spliter import NotebookSplitter

splitter = NotebookSplitter()
Image(splitter.workflow.get_graph().draw_mermaid_png())

# %%
from IPython.display import Image

from systemverilog_agent import SystemVerilogCodeGenerator

systemverilog = SystemVerilogCodeGenerator()
Image(systemverilog.graph.get_graph().draw_mermaid_png())
